# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
delhi_air=pd.read_csv("delhi_aqi.csv")
delhi_air
# Out:
#                   date       co     no     no2     o3     so2   pm2_5    pm10  \
# 0      11/25/2020 1:00  2616.88   2.18   70.60  13.59   38.62  364.61  411.73
# 1      11/25/2020 2:00  3631.59  23.25   89.11   0.33   54.36  420.96  486.21
# 2      11/25/2020 3:00  4539.49  52.75  100.08   1.11   68.67  463.68  541.95
# 3      11/25/2020 4:00  4539.49  50.96  111.04   6.44   78.20  454.81  534.00
# 4      11/25/2020 5:00  4379.27  42.92  117.90  17.17   87.74  448.14  529.19
# ...                ...      ...    ...     ...    ...     ...     ...     ...
# 18771   1/24/2023 4:00  1762.39   4.64   37.01  33.26   30.52  231.15  289.84
# 18772   1/24/2023 5:00  1735.69   6.82   34.96  46.49   34.33  225.08  280.52
# 18773   1/24/2023 6:00  1922.61   8.16   40.10  56.51   43.39  242.49  296.07
# 18774   1/24/2023 7:00  1361.85   9.05   52.78  71.53  100.14  165.67  191.82
# 18775   1/24/2023 8:00  1134.87   8.61   56.89  80.11  110.63  123.76  140.26
#
#          nh3
# 0      28.63
# ...

# %%
delhi_air.shape
# Out:
# (18776, 9)

# %%
delhi_air.head()
# Out:
#               date       co     no     no2     o3    so2   pm2_5    pm10  \
# 0  11/25/2020 1:00  2616.88   2.18   70.60  13.59  38.62  364.61  411.73
# 1  11/25/2020 2:00  3631.59  23.25   89.11   0.33  54.36  420.96  486.21
# 2  11/25/2020 3:00  4539.49  52.75  100.08   1.11  68.67  463.68  541.95
# 3  11/25/2020 4:00  4539.49  50.96  111.04   6.44  78.20  454.81  534.00
# 4  11/25/2020 5:00  4379.27  42.92  117.90  17.17  87.74  448.14  529.19
#
#      nh3
# 0  28.63
# 1  41.04
# 2  49.14
# 3  48.13
# 4  46.61

# %%
delhi_air.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18776 entries, 0 to 18775
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    18776 non-null  object
#  1   co      18776 non-null  float64
#  2   no      18776 non-null  float64
#  3   no2     18776 non-null  float64
#  4   o3      18776 non-null  float64
#  5   so2     18776 non-null  float64
#  6   pm2_5   18776 non-null  float64
#  7   pm10    18776 non-null  float64
#  8   nh3     18776 non-null  float64
# dtypes: float64(8), object(1)
# memory usage: 1.3+ MB

# %%
delhi_air.select_dtypes(['object']).head()
# Out:
#               date
# 0  11/25/2020 1:00
# 1  11/25/2020 2:00
# 2  11/25/2020 3:00
# 3  11/25/2020 4:00
# 4  11/25/2020 5:00

# %%
delhi_air['date'] = pd.to_datetime(delhi_air.date)
delhi_air['date']
# Out:
# 0       2020-11-25 01:00:00
# 1       2020-11-25 02:00:00
# 2       2020-11-25 03:00:00
# 3       2020-11-25 04:00:00
# 4       2020-11-25 05:00:00
#                 ...
# 18771   2023-01-24 04:00:00
# 18772   2023-01-24 05:00:00
# 18773   2023-01-24 06:00:00
# 18774   2023-01-24 07:00:00
# 18775   2023-01-24 08:00:00
# Name: date, Length: 18776, dtype: datetime64[ns]

# %%
delhi_air.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18776 entries, 0 to 18775
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    18776 non-null  datetime64[ns]
#  1   co      18776 non-null  float64
#  2   no      18776 non-null  float64
#  3   no2     18776 non-null  float64
#  4   o3      18776 non-null  float64
#  5   so2     18776 non-null  float64
#  6   pm2_5   18776 non-null  float64
#  7   pm10    18776 non-null  float64
#  8   nh3     18776 non-null  float64
# dtypes: datetime64[ns](1), float64(8)
# memory usage: 1.3 MB

# %%
#plt.figure(figsize=(7,5))
delhi_air.corr().style.background_gradient(cmap="GnBu")
# Out:
# <style type="text/css">
# #T_c088e_row0_col0, #T_c088e_row1_col1, #T_c088e_row2_col2, #T_c088e_row3_col3, #T_c088e_row4_col4, #T_c088e_row5_col5, #T_c088e_row6_col6, #T_c088e_row7_col7, #T_c088e_row8_col8 {
#   background-color: #084081;
#   color: #f1f1f1;
# }
# #T_c088e_row0_col1 {
#   background-color: #c4e8c1;
#   color: #000000;
# }
# #T_c088e_row0_col2 {
#   background-color: #c6e9c2;
#   color: #000000;
# }
# #T_c088e_row0_col3, #T_c088e_row0_col4 {
#   background-color: #ccebc5;
#   color: #000000;
# }
# #T_c088e_row0_col5, #T_c088e_row1_col4, #T_c088e_row4_col0, #T_c088e_row4_col1, #T_c088e_row4_col2, #T_c088e_row4_col3, #T_c088e_row4_col6, #T_c088e_row4_col7, #T_c088e_row4_col8, #T_c088e_row6_col0 {
#   background-color: #f7fcf0;
#   color: #000000;
# }
# #T_c088e_row0_col6 {
#   background-color: #d7efd1;
#   color: #000000;
# }
# #T_c088e_row0_col7 {
#   background-color: #d5efcf;
#   color: #000000;
# }
# #T_c088e_row0_col8 {
#   background-color: #d1edca;
# ...

# %%
delhi_air.describe()
# Out:
#                                 date            co            no  \
# count                          18776  18776.000000  18776.000000
# mean   2021-12-23 14:35:34.384320256   2929.228628     33.660702
# min              2020-11-25 01:00:00    260.350000      0.000000
# 25%              2021-06-09 14:45:00   1068.120000      0.680000
# 50%              2021-12-22 04:30:00   1842.500000      5.250000
# 75%              2022-07-07 18:15:00   3685.000000     35.760000
# max              2023-01-24 08:00:00  21148.680000    500.680000
# std                              NaN   2854.523506     62.127118
#
#                 no2            o3           so2         pm2_5          pm10  \
# count  18776.000000  18776.000000  18776.000000  18776.000000  18776.000000
# mean      66.221299     60.346239     66.693633    238.130309    300.092966
# min        4.280000      0.000000      5.250000     11.830000     15.070000
# ...

# %%
delhi_air.pm10.skew()
# Out:
# 1.867980925000639

# %%
sns.pairplot(delhi_air[['co','no2','pm2_5','pm10']])
# Out:
# C:\Users\Samsung\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
delhi_air[['co','no','no2','so2','pm2_5','pm10','nh3']].mean()
# Out:
# co       2929.228628
# no         33.660702
# no2        66.221299
# so2        66.693633
# pm2_5     238.130309
# pm10      300.092966
# nh3        25.109815
# dtype: float64

# %%
plt.figure (figsize=(7,4))
sns.set_style("white")

plt.title("Correlation matrix of features")
sns.heatmap(data=delhi_air.corr(),linewidth=0.5,cmap="coolwarm",annot=True )
plt.show()

# %%
plt.figure(figsize=(15, 6))
sns.set_style("white")
plt.subplot(141)
sns.lineplot(data=delhi_air, x="co", y="pm10")

plt.subplot(142)
sns.lineplot(data=delhi_air, x="pm2_5", y="pm10")

plt.subplot(143)
sns.lineplot(data=delhi_air, x="no", y="pm10")

plt.subplot(144)
sns.lineplot(data=delhi_air, x="no2", y="pm10")
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.subplot(1,2,1)
sns.histplot(delhi_air["pm10"],color="red",kde=True)
plt.title("pm10 Distribution",fontweight="black",pad=10,fontsize=10)
plt.subplot(1,2,2)
sns.boxplot(delhi_air["pm10"])
plt.title("pm10 Spread",fontweight="black",pad=10,fontsize=10)

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.boxplot(data=delhi_air)
plt.show()

# %%
plt.figure(figsize=(4,5))
plt.style.use('ggplot')
delhi_air['pm10'].value_counts().plot(kind='pie')
plt.show()

# %%
#using countplot
plt.figure(figsize=(6,7))
plt.style.use('ggplot')
sns.countplot(x='pm10',data=delhi_air)
# Out:
# <Axes: xlabel='pm10', ylabel='count'>

# %% [markdown]
# ## After Removing Outliers

# %%
for cols in delhi_air.columns[:-1]:
    if delhi_air[cols].dtype == object:
        continue
    else:
        Q1 = delhi_air[cols].quantile(q=0.25)
        Q3 = delhi_air[cols].quantile(q=0.75)
        iqr = Q3 - Q1
    
        low = Q1 - 1.5*(Q3-Q1)
        high = Q3 + 1.5*(Q3-Q1)
        delhi_air.loc[ (delhi_air[cols]>high)] = delhi_air[cols].median()

# %%
plt.figure(figsize=(15, 6))
sns.set_style("white")
plt.subplot(141)
sns.lineplot(data=delhi_air, x="co", y="pm10")

plt.subplot(142)
sns.lineplot(data=delhi_air, x="pm2_5", y="pm10")

plt.subplot(143)
sns.lineplot(data=delhi_air, x="no", y="pm10")

plt.subplot(144)
sns.lineplot(data=delhi_air, x="no2", y="pm10")
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.subplot(1,2,1)
sns.histplot(delhi_air["pm10"],color="red",kde=True)
plt.title("pm10 Distribution",fontweight="black",pad=10,fontsize=10)
plt.subplot(1,2,2)
sns.boxplot(delhi_air["pm10"])
plt.title("pm10 Spread",fontweight="black",pad=10,fontsize=10)

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(4,5))
plt.style.use('ggplot')
delhi_air['pm2_5'].value_counts().plot(kind='pie')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.boxplot(data=delhi_air)
plt.show()

# %%
# removing outliers
x = delhi_air.drop(['date','pm10'], axis=1)
y = delhi_air.pm10

# %%
x
# Out:
#              co      no     no2      o3      so2    pm2_5     nh3
# 0      2616.880   2.180  70.600  13.590   38.620  364.610  28.630
# 1        82.275  82.275  82.275  82.275   82.275   82.275  82.275
# 2        82.275  82.275  82.275  82.275   82.275   82.275  82.275
# 3        82.275  82.275  82.275  82.275   82.275   82.275  82.275
# 4        82.275  82.275  82.275  82.275   82.275   82.275  82.275
# ...         ...     ...     ...     ...      ...      ...     ...
# 18771  1762.390   4.640  37.010  33.260   30.520  231.150   6.270
# 18772  1735.690   6.820  34.960  46.490   34.330  225.080   9.120
# 18773  1922.610   8.160  40.100  56.510   43.390  242.490  12.540
# 18774  1361.850   9.050  52.780  71.530  100.140  165.670   7.470
# 18775    40.050  40.050  40.050  40.050   40.050   40.050  40.050
#
# [18776 rows x 7 columns]

# %%
y
# Out:
# 0        411.730
# 1         82.275
# 2         82.275
# 3         82.275
# 4         82.275
#           ...
# 18771    289.840
# 18772    280.520
# 18773    296.070
# 18774    191.820
# 18775     40.050
# Name: pm10, Length: 18776, dtype: float64

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test= train_test_split(x, y, test_size=0.20, 
                                                   random_state=0)

# %%
print('x_train shape:', x_train.shape)
print('x_test shape:', x_test.shape)
print('y_train shape:', y_train.shape)
print('y_test shape:', y_test.shape)
# Out:
# x_train shape: (15020, 7)
# x_test shape: (3756, 7)
# y_train shape: (15020,)
# y_test shape: (3756,)

# %%
x_train
# Out:
#             co     no    no2      o3    so2   pm2_5    nh3
# 13517   413.89   0.67  10.88  128.75  19.07   22.11   8.49
# 122       5.25   5.25   5.25    5.25   5.25    5.25   5.25
# 1602      5.25   5.25   5.25    5.25   5.25    5.25   5.25
# 6164   1949.31  15.87  41.13    0.01  22.65  158.84   5.00
# 13023  1548.77   0.00  52.78   63.66  66.76   96.60  26.85
# ...        ...    ...    ...     ...    ...     ...    ...
# 9225   2056.12   9.16  73.34   92.98  63.90  206.89  19.76
# 13123  1562.12   5.87  47.30    0.64  27.66  107.56  24.83
# 9845   3177.64  40.68  62.38   32.19  75.34  245.03  22.55
# 10799   934.60   0.00  20.39   67.95  25.51  118.38   7.09
# 2732   1321.79   2.38  47.98    2.41  20.27   78.42  21.79
#
# [15020 rows x 7 columns]

# %%
x_test
# Out:
#             co     no    no2      o3    so2   pm2_5    nh3
# 10633     5.25   5.25   5.25    5.25   5.25    5.25   5.25
# 14709   988.01   7.38  37.01    0.10  56.27   55.05   4.37
# 15546  1789.09   0.00  60.32   46.49  42.92  186.32  25.08
# 18367  1535.42   7.60  42.50  114.44  60.56  178.09  11.27
# 15445   700.95   0.00  31.87   50.78  25.03   22.49  12.54
# ...        ...    ...    ...     ...    ...     ...    ...
# 14198     5.25   5.25   5.25    5.25   5.25    5.25   5.25
# 15155   460.62   0.81  20.73   80.11  27.18   23.72   6.90
# 1281   1121.52   3.16  36.67  151.63  81.06  269.77   2.19
# 14673  1428.60  12.52  58.26   20.38  63.90   53.55  17.48
# 8164     42.84  42.84  42.84   42.84  42.84   42.84  42.84
#
# [3756 rows x 7 columns]

# %%
y_train
# Out:
# 13517     50.57
# 122        5.25
# 1602       5.25
# 6164     184.69
# 13023    128.97
#           ...
# 9225     240.54
# 13123    250.55
# 9845     301.85
# 10799    131.11
# 2732     113.60
# Name: pm10, Length: 15020, dtype: float64

# %%
y_test
# Out:
# 10633      5.25
# 14709     61.74
# 15546    227.57
# 18367    196.41
# 15445     39.30
#           ...
# 14198      5.25
# 15155     28.61
# 1281     282.82
# 14673     74.86
# 8164      42.84
# Name: pm10, Length: 3756, dtype: float64

# %%
from sklearn.linear_model import LinearRegression

car_model = LinearRegression()
car_model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
m = car_model.coef_
c = car_model.intercept_

m,c
# Out:
# (array([ 0.03218611, -0.46119243, -0.27375455,  0.13634163, -0.20237554,
#          0.91934721,  0.82395317]),
#  3.3570977925455736)

# %%
y_pred_train = car_model.predict(x_train)
y_pred_train
# Out:
# array([ 54.40797346,   8.47325224,   8.47325224, ..., 302.78452153,
#        146.63234988, 117.94358002])

# %%
y_pred_test = car_model.predict(x_test)
y_pred_test
# Out:
# array([  8.47325224,  64.45874692, 234.03816118, ..., 282.04419621,
#         81.09570223,  45.10491807])

# %%
from sklearn.metrics import mean_squared_error, r2_score

mean_squared_error(y_test, y_pred_test)
# Out:
# 732.0299144278182

# %%
accuracy = r2_score(y_test, y_pred_test)
print("the model has an accuracy of", accuracy*100)
# Out:
# the model has an accuracy of 93.74280515998792

# %%
r2score_train= r2_score(y_train, y_pred_train)
r2score_train
# Out:
# 0.9341785237560265

# %%
r2score_test= r2_score(y_test, y_pred_test)
r2score_test
# Out:
# 0.9374280515998792

# %%
car_df = pd.DataFrame({"Actual": y_test,
                       "Predicted": y_pred_test,
                       "Error": abs(y_test-y_pred_test)})

car_df.head().style.background_gradient(cmap="RdYlGn")
# Out:
# <style type="text/css">
# #T_6aff9_row0_col0, #T_6aff9_row0_col1, #T_6aff9_row1_col2 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_6aff9_row0_col2 {
#   background-color: #b50f26;
#   color: #f1f1f1;
# }
# #T_6aff9_row1_col0 {
#   background-color: #f99153;
#   color: #000000;
# }
# #T_6aff9_row1_col1 {
#   background-color: #f88c51;
#   color: #f1f1f1;
# }
# #T_6aff9_row2_col0, #T_6aff9_row2_col1, #T_6aff9_row3_col2 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_6aff9_row2_col2 {
#   background-color: #f98e52;
#   color: #f1f1f1;
# }
# #T_6aff9_row3_col0 {
#   background-color: #36a657;
#   color: #f1f1f1;
# }
# #T_6aff9_row3_col1 {
#   background-color: #16914d;
#   color: #f1f1f1;
# }
# #T_6aff9_row4_col0 {
#   background-color: #e65036;
#   color: #f1f1f1;
# }
# #T_6aff9_row4_col1 {
#   background-color: #ef633f;
#   color: #f1f1f1;
# }
# #T_6aff9_row4_col2 {
#   background-color: #eff8aa;
#   color: #000000;
# }
# </style>
# <table id="T_6aff9">
# ...

# %%
car_df.Error.describe()
# Out:
# count    3756.000000
# mean       13.283874
# std        23.573641
# min         0.006479
# 25%         2.582068
# 50%         5.691585
# 75%        15.659887
# max       292.702635
# Name: Error, dtype: float64

# %%
plt.style.use('ggplot')
plt.figure(figsize=(8,6))
sns.regplot(x=y_test, 
            y=y_pred_test, 
            ci=None, 
            color="r")

plt.suptitle("Correlation Plot")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,4))
sns.set_style('darkgrid')

plt.scatter(x=range(13),
           y=y_test.head(13),
           color="#1abc9c",
           label="Actual Points")
plt.scatter(x=range(13),
           y=y_pred_test[:13],
           color="#2980b9",
           label="Predicted Points")

plt.suptitle("Actual Points vs. Predicted Points")
plt.legend(shadow=True,
           loc="best")
plt.show()

# %%
x_test.tail()
# Out:
#             co     no    no2      o3    so2   pm2_5    nh3
# 14198     5.25   5.25   5.25    5.25   5.25    5.25   5.25
# 15155   460.62   0.81  20.73   80.11  27.18   23.72   6.90
# 1281   1121.52   3.16  36.67  151.63  81.06  269.77   2.19
# 14673  1428.60  12.52  58.26   20.38  63.90   53.55  17.48
# 8164     42.84  42.84  42.84   42.84  42.84   42.84  42.84
